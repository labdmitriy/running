# %% [markdown]
# Links:
# https://towardsdatascience.com/how-tracking-apps-analyse-your-gps-data-a-hands-on-tutorial-in-python-756d4db6715d

# %%
from pathlib import Path
from tqdm import tqdm

import gpxpy
import gmplot
import mplleaflet

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gpx_dir = Path('./data')

# %%
points_list = []

for gpx_file in list(gpx_dir.glob('*.gpx')):
    with open(gpx_file, 'r') as f:
        gpx = gpxpy.parse(f)
        
    data = gpx.tracks[0].segments[0].points
    
    for point in data:
        points_list.append({'file_name': gpx_file.name, 
                            'lon': point.longitude, 'lat' : point.latitude, 
                            'alt' : point.elevation, 'time' : point.time})
        
df = pd.DataFrame(points_list)
print(df.shape)
df.head()
# Out:
# (24535, 5)
#                file_name        lon        lat    alt  \
# 0  2019-10-25-124012.gpx  38.122954  55.591768  132.2
# 1  2019-10-25-124012.gpx  38.122846  55.591700  132.1
# 2  2019-10-25-124012.gpx  38.122709  55.591648  132.1
# 3  2019-10-25-124012.gpx  38.122554  55.591595  132.1
# 4  2019-10-25-124012.gpx  38.122378  55.591554  132.1
#
#                        time
# 0 2019-10-25 09:40:12+00:00
# 1 2019-10-25 09:40:18+00:00
# 2 2019-10-25 09:40:21+00:00
# 3 2019-10-25 09:40:24+00:00
# 4 2019-10-25 09:40:29+00:00

# %%
fig, axes = plt.subplots(figsize=(8, 16))

for gpx_file in list(gpx_dir.glob('*.gpx')):
    route_df = df[df['file_name'] == gpx_file.name]
    plt.plot(route_df['lon'], route_df['lat'], linewidth=3)
    
mplleaflet.display(fig=fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="960"></iframe>
