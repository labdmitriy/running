# %% [markdown]
# Links:
# https://towardsdatascience.com/how-tracking-apps-analyse-your-gps-data-a-hands-on-tutorial-in-python-756d4db6715d

# %%
from pathlib import Path
from tqdm import tqdm

import gpxpy
import gmplot
import mplleaflet

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gpx_dir = Path('./data')

# %%
points_list = []

for gpx_file in list(gpx_dir.glob('*.gpx')):
    with open(gpx_file, 'r') as f:
        gpx = gpxpy.parse(f)
        
    data = gpx.tracks[0].segments[0].points
    
    for point in data:
        points_list.append({'file_name': gpx_file.name, 
                            'lon': point.longitude, 'lat' : point.latitude, 
                            'alt' : point.elevation, 'time' : point.time})
        
df = pd.DataFrame(points_list)
print(df.shape)
df.head()
# Out:
# (66369, 5)
#         file_name        lon        lat    alt                      time
# 0  3310068113.gpx  38.103377  55.604559  126.0 2019-09-16 08:43:28+00:00
# 1  3310068113.gpx  38.103415  55.604542  126.0 2019-09-16 08:43:29+00:00
# 2  3310068113.gpx  38.103539  55.604474  126.0 2019-09-16 08:43:36+00:00
# 3  3310068113.gpx  38.103720  55.604429  126.0 2019-09-16 08:43:42+00:00
# 4  3310068113.gpx  38.103895  55.604387  126.0 2019-09-16 08:43:46+00:00

# %%
fig, axes = plt.subplots(figsize=(8, 16))

for gpx_file in list(gpx_dir.glob('*.gpx')):
    route_df = df[df['file_name'] == gpx_file.name]
    plt.plot(route_df['lon'], route_df['lat'], linewidth=3)
    
mplleaflet.display(fig=fig)
# Out:
# /opt/anaconda3/envs/ml/lib/python3.6/site-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="data:text/html;base64,..." width="100%" height="960"></iframe>
